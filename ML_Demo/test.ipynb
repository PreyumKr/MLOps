# %%
import numpy as np

# %%
a = np.array(1)

# %%
a.ndim
# Out:
# 0

# %%
b = np.array([1])
c = np.array([[1]])

# %%
b.ndim
# Out:
# 1

# %%
c.ndim
# Out:
# 2

# %%
# Nested Arrays form the dimension in Numpy.
